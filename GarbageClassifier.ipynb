# %% [markdown]
# <a href="https://colab.research.google.com/github/swatidamele/FinalProject/blob/main/GarbageClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential
import os, glob

# %%
base_path = '../Garbage%20classification/cardboard'

img_list = glob.glob(os.path.join(base_path, '*/*.jpg'))

print(len(img_list))
# Out:
# 0
